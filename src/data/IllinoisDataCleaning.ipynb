# %%
import pandas as pd
df = pd.read_csv("./illinoisAdaptedResults.csv")

# %%
df["NAME"] = df["NAME"] + ' ' + df['COUNTYFP'].astype(str)

# %%
df.head()
# Out:
#    COUNTYFP              NAME  G16PREDCLI  G16PRERTRU  G16PRELJOH  G16PREGSTE  \
# 0         1     CLAYTON 1 1 1          76         359          10           1
# 1         1   NORTHEAST 1 1 1          72         350          17           5
# 2         1  CAMP POINT 1 1 1          69         331          12           3
# 3         1  CAMP POINT 2 1 1          47         376           9           2
# 4         1      MENDON 2 1 1          73         320           9           1
#
#    G16PREOWRI  G16USSDDUC  G16USSRKIR  G16USSLMCM  G16USSGSUM  G16USSOWRI  \
# 0           2         175         260           5           7           0
# 1           1         138         283          16           6           0
# 2           1         118         267          12           9           0
# 3           0         118         296           7           6           0
# 4           0         150         227          14           8           0
#
# ...

# %%
cleaned = df.loc[:,["NAME", "G16PREDCLI", "G16PRERTRU","NEIGHBOR"]]

# %%
cleaned
# Out:
#                         NAME  G16PREDCLI  G16PRERTRU  \
# 0                CLAYTON 1 1          76         359
# 1              NORTHEAST 1 1          72         350
# 2             CAMP POINT 1 1          69         331
# 3             CAMP POINT 2 1          47         376
# 4                 MENDON 2 1          73         320
# ...                      ...         ...         ...
# 10085   GALESBURG CITY 12 95         208         182
# 10086   GALESBURG CITY 14 95         320         145
# 10087  GALESBURG TOWNSHIP 95          63         128
# 10088    GALESBURG CITY 1 95         253         271
# 10089         OSWEGO - 04 93         443         319
#
#                                                 NEIGHBOR
# 0      PEA RIDGE 9,CAMP POINT 1 1,NORTHEAST 1 1,HOUST...
# 1      BIRMINGHAM 169,CHILI 67,AUGUSTA 67,CLAYTON 1 1...
# 2      CLAYTON 1 1,CAMP POINT 2 1,NORTHEAST 1 1,HOUST...
# 3      HONEY CREEK 1 1,KEENE 1 1,CAMP POINT 1 1,HOUST...
# ...

# %%
cleaned.to_csv("./cleanedIllinois.csv", index = False)
