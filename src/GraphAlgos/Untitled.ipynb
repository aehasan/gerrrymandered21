# %%
import pandas as pd

# %%
df = pd.read_csv("./illinoisDistricts.csv")

# %%
df.head()
# Out:
#    COUNTYFP          NAME  G16PREDCLI  G16PRERTRU  G16PRELJOH  G16PREGSTE  \
# 0         1     CLAYTON 1          76         359          10           1
# 1         1   NORTHEAST 1          72         350          17           5
# 2         1  CAMP POINT 1          69         331          12           3
# 3         1  CAMP POINT 2          47         376           9           2
# 4         1      MENDON 2          73         320           9           1
#
#    G16PREOWRI  G16USSDDUC  G16USSRKIR  G16USSLMCM  G16USSGSUM  G16USSOWRI  \
# 0           2         175         260           5           7           0
# 1           1         138         283          16           6           0
# 2           1         118         267          12           9           0
# 3           0         118         296           7           6           0
# 4           0         150         227          14           8           0
#
#    G16COMDMEN  G16COMRMUN  G16COMLBAL  G16COMGCUR  \
# 0         117         299          10           9
# 1         118         299          17           5
# 2          94         294           9          12
# 3          97         309          10           7
# 4         125         252          17           3
#
#                                            NEIGHBORS  SUM
# 0  PEA RIDGE,CAMP POINT 1,NORTHEAST 1,HOUSTON 1,H...  274
# 1  BIRMINGHAM,CHILI,AUGUSTA,CLAYTON 1,CAMP POINT ...  319
# 2  CLAYTON 1,CAMP POINT 2,NORTHEAST 1,HOUSTON 1,C...  246
# 3  HONEY CREEK 1,KEENE 1,CAMP POINT 1,HOUSTON 1,G...  318
# 4                                           MENDON 1   38

# %%
dffinal = df.loc[:, ["NAME", "G16PREDCLI", "G16PRERTRU", "NEIGHBORS"]]

# %%
dffinal
# Out:
#                      NAME  G16PREDCLI  G16PRERTRU  \
# 0               CLAYTON 1          76         359
# 1             NORTHEAST 1          72         350
# 2            CAMP POINT 1          69         331
# 3            CAMP POINT 2          47         376
# 4                MENDON 2          73         320
# ...                   ...         ...         ...
# 10085   GALESBURG CITY 12         208         182
# 10086   GALESBURG CITY 14         320         145
# 10087  GALESBURG TOWNSHIP          63         128
# 10088    GALESBURG CITY 1         253         271
# 10089         OSWEGO - 04         443         319
#
#                                                NEIGHBORS
# 0      PEA RIDGE,CAMP POINT 1,NORTHEAST 1,HOUSTON 1,H...
# 1      BIRMINGHAM,CHILI,AUGUSTA,CLAYTON 1,CAMP POINT ...
# 2      CLAYTON 1,CAMP POINT 2,NORTHEAST 1,HOUSTON 1,C...
# 3      HONEY CREEK 1,KEENE 1,CAMP POINT 1,HOUSTON 1,G...
# 4                                               MENDON 1
# ...                                                  ...
# 10085  GALESBURG CITY 7,KNOX 5,KNOX 7,GALESBURG CITY ...
# 10086  GALESBURG CITY 21,GALESBURG CITY 22,GALESBURG ...
# 10087  KELLY,HENDERSON 2,GALESBURG CITY 23,GALESBURG ...
# 10088  GALESBURG CITY 23,HENDERSON 1,GALESBURG CITY 2...
# 10089  9-4,OSWEGO - 34,OSWEGO - 37 AU01,AU10,W07P06,O...
#
# [10090 rows x 4 columns]

# %%
dffinal.to_csv("illinoisDistrictsTrimmed.csv", index = False)
